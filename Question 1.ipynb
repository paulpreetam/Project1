# %%
#Question 1: Initial Trends on Passengers and Flights

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in CSV
data2019 = pd.read_csv("Resources/BoT.DataPassengersFlight2019.csv")
data2020 = pd.read_csv("Resources/BoT.DataPassengersFlight2020.csv")

# %%
data2019
# Out:
#     Year Month DomesticPassengers InternationalPassengers TotalPassengers  \
# 0   2019   Jan         58,034,262              18,690,817      76,725,079
# 1   2019   Feb         55,679,481              16,280,536      71,960,017
# 2   2019   Mar         70,234,684              20,295,947      90,530,631
# 3   2019   Apr         66,938,654              20,019,304      86,957,958
# 4   2019   May         71,365,660              20,995,113      92,360,773
# 5   2019   Jun         72,790,418              22,747,453      95,537,871
# 6   2019   Jul         75,281,916              23,907,859      99,189,775
# 7   2019   Aug         72,729,540              23,239,338      95,968,878
# 8   2019   Sep         63,991,365              18,842,310      82,833,675
# 9   2019   Oct         69,936,836              18,973,444      88,910,280
# 10  2019   Nov         64,827,417              17,575,113      82,402,530
# 11  2019   Dec         69,737,526              19,859,635      89,597,161
#
# ...

# %%
data2020
# Out:
#     Year Month DomesticPassengers InternationalPassengers TotalPassengers  \
# 0   2020   Jan         61,626,465              18,946,132      80,572,597
# 1   2020   Feb         59,861,408              15,823,231      75,684,639
# 2   2020   Mar         34,417,701               8,927,886      43,345,587
# 3   2020   Apr          2,879,556                 396,394       3,275,950
# 4   2020   May          8,238,757                 369,317       8,608,074
# 5   2020   Jun         16,207,969                 801,741      17,009,710
# 6   2020   Jul         22,878,828               1,853,462      24,732,290
# 7   2020   Aug         23,910,340               2,267,701      26,178,041
# 8   2020   Sep         23,854,435               2,265,050      26,119,485
# 9   2020   Oct         28,026,415               2,951,660      30,978,075
# 10  2020   Nov         26,290,900               3,514,555      29,805,455
#
#    DomesticFlights InternationalFlights TotalFlights
# ...

# %%
combined = pd.merge(data2019, data2020, how="outer", on=["Year","Month"])
combined
# Out:
#     Year Month DomesticPassengers_x InternationalPassengers_x  \
# 0   2019   Jan           58,034,262                18,690,817
# 1   2019   Feb           55,679,481                16,280,536
# 2   2019   Mar           70,234,684                20,295,947
# 3   2019   Apr           66,938,654                20,019,304
# 4   2019   May           71,365,660                20,995,113
# 5   2019   Jun           72,790,418                22,747,453
# 6   2019   Jul           75,281,916                23,907,859
# 7   2019   Aug           72,729,540                23,239,338
# 8   2019   Sep           63,991,365                18,842,310
# 9   2019   Oct           69,936,836                18,973,444
# 10  2019   Nov           64,827,417                17,575,113
# 11  2019   Dec           69,737,526                19,859,635
# 12  2020   Jan                  NaN                       NaN
# 13  2020   Feb                  NaN                       NaN
# ...

# %%
combined.head()
# Out:
#    Year Month DomesticPassengers_x InternationalPassengers_x  \
# 0  2019   Jan           58,034,262                18,690,817
# 1  2019   Feb           55,679,481                16,280,536
# 2  2019   Mar           70,234,684                20,295,947
# 3  2019   Apr           66,938,654                20,019,304
# 4  2019   May           71,365,660                20,995,113
#
#   TotalPassengers_x DomesticFlights_x InternationalFlights_x TotalFlights_x  \
# 0        76,725,079           667,659                135,773        803,432
# 1        71,960,017           608,029                119,724        727,753
# 2        90,530,631           729,251                140,966        870,217
# 3        86,957,958           709,126                141,759        850,885
# 4        92,360,773           740,639                139,760        880,399
#
#   DomesticPassengers_y InternationalPassengers_y TotalPassengers_y  \
# 0                  NaN                       NaN               NaN
# ...

# %%
combined = combined.rename(columns={"DomesticPassengers_x": "Domestic Passengers 2019", "DomesticPassengers_y": "Domestic Passengers 2020"})

# %%
newdf = combined[['Month','Domestic Passengers 2019','Domestic Passengers 2020']]
#newdf['Domestic Passengers 2019'].replace(0, np.nan, inplace = True)
newdf.fillna(0, inplace = True)
# Out:
# C:\Users\pulle\anaconda3\lib\site-packages\pandas\core\frame.py:4317: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
newdf.isnull().sum()
# Out:
# Month                       0
# Domestic Passengers 2019    0
# Domestic Passengers 2020    0
# dtype: int64

# %%
newdf
# Out:
#    Month Domestic Passengers 2019 Domestic Passengers 2020
# 0    Jan               58,034,262                        0
# 1    Feb               55,679,481                        0
# 2    Mar               70,234,684                        0
# 3    Apr               66,938,654                        0
# 4    May               71,365,660                        0
# 5    Jun               72,790,418                        0
# 6    Jul               75,281,916                        0
# 7    Aug               72,729,540                        0
# 8    Sep               63,991,365                        0
# 9    Oct               69,936,836                        0
# 10   Nov               64,827,417                        0
# 11   Dec               69,737,526                        0
# 12   Jan                        0               61,626,465
# 13   Feb                        0               59,861,408
# 14   Mar                        0               34,417,701
# ...

# %%
newdf.groupby('Month').sum()
# Out:
#       Domestic Passengers 2019  Domestic Passengers 2020
# Month
# Apr                        NaN                       NaN
# Aug                        NaN                       NaN
# Dec                 69,737,526                       0.0
# Feb                        NaN                       NaN
# Jan                        NaN                       NaN
# Jul                        NaN                       NaN
# Jun                        NaN                       NaN
# Mar                        NaN                       NaN
# May                        NaN                       NaN
# Nov                        NaN                       NaN
# Oct                        NaN                       NaN
# Sep                        NaN                       NaN

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 0 to 22
# Data columns (total 3 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Month                     23 non-null     object
#  1   Domestic Passengers 2019  23 non-null     object
#  2   Domestic Passengers 2020  23 non-null     object
# dtypes: object(3)
# memory usage: 1.3+ KB

# %%
newdf['Domestic Passengers 2019'] = newdf['Domestic Passengers 2019'].str.replace(",","")
# Out:
# <ipython-input-15-588055e8513c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['Domestic Passengers 2019'] = newdf['Domestic Passengers 2019'].str.replace(",","")

# %%
newdf['Domestic Passengers 2020'] = newdf['Domestic Passengers 2020'].str.replace(",","")
# Out:
# <ipython-input-16-35c3451a7e62>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['Domestic Passengers 2020'] = newdf['Domestic Passengers 2020'].str.replace(",","")

# %%
newdf['Domestic Passengers 2019'].fillna(0, inplace = True)
# Out:
# C:\Users\pulle\anaconda3\lib\site-packages\pandas\core\series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
newdf['Domestic Passengers 2020'].fillna(0, inplace = True)

# %%
newdf['Domestic Passengers 2019'] = newdf['Domestic Passengers 2019'].astype(int)
# Out:
# <ipython-input-19-cb0bea141e55>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['Domestic Passengers 2019'] = newdf['Domestic Passengers 2019'].astype(int)

# %%
newdf['Domestic Passengers 2020'] = newdf['Domestic Passengers 2020'].astype(int)
# Out:
# <ipython-input-20-01949cb3aff9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['Domestic Passengers 2020'] = newdf['Domestic Passengers 2020'].astype(int)

# %%
newdf1 = newdf.groupby('Month')
newdf1.sum()
# Out:
#        Domestic Passengers 2019  Domestic Passengers 2020
# Month
# Apr                    66938654                   2879556
# Aug                    72729540                  23910340
# Dec                    69737526                         0
# Feb                    55679481                  59861408
# Jan                    58034262                  61626465
# Jul                    75281916                  22878828
# Jun                    72790418                  16207969
# Mar                    70234684                  34417701
# May                    71365660                   8238757
# Nov                    64827417                  26290900
# Oct                    69936836                  28026415
# Sep                    63991365                  23854435

# %%
sum_df= newdf1.sum()

# %%
sum_df = sum_df.reindex(["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov"])
sum_df
# Out:
#        Domestic Passengers 2019  Domestic Passengers 2020
# Month
# Jan                    58034262                  61626465
# Feb                    55679481                  59861408
# Mar                    70234684                  34417701
# Apr                    66938654                   2879556
# May                    71365660                   8238757
# Jun                    72790418                  16207969
# Jul                    75281916                  22878828
# Aug                    72729540                  23910340
# Sep                    63991365                  23854435
# Oct                    69936836                  28026415
# Nov                    64827417                  26290900

# %%
plt.plot(sum_df)
plt.title("Domestic Passengers in 2019 vs 2020")
plt.xlabel("Months")
plt.ylabel("Passengers per Year x 10 million")
# Out:
# Text(0, 0.5, 'Passengers per Year x 10 million')
